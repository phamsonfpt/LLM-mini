# %%
import pandas as pd

# %%
df = pd.read_csv('ragbench_hotpotqa_20260625_025829.csv')
print(df)
# Out:
#               notebook_id                                           question  \
# 0  ragbench_hotpotqa_0000  Which university did one of the key figures in...
# 1  ragbench_hotpotqa_0001  Were both Léopold Eyharts and Ulrich Walter a ...
# 2  ragbench_hotpotqa_0002  Which music group has the most members, DC Tal...
# 3  ragbench_hotpotqa_0003  Eddie Jemison had a role in the television ser...
# 4  ragbench_hotpotqa_0004  Consider the band formed in 2015 by JYP Entert...
# 5  ragbench_hotpotqa_0005  What three categories does income get levied u...
# 6  ragbench_hotpotqa_0006  What city did the author of "Portraits and Pra...
# 7  ragbench_hotpotqa_0007  Are both Frank Lloyd and Olivier Assayas Ameri...
# 8  ragbench_hotpotqa_0008  Which founder of Alcatraz East was born on Mar...
# 9  ragbench_hotpotqa_0009  Which magazine was first published earlier, Th...
#
#                                            documents  \
# 0  The Brooklyn Nets are an American professional...
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 200)

df = pd.read_csv('ragbench_hotpotqa_20260625_025829.csv', encoding='utf-8-sig')

# Xem từng hàng rõ ràng
df.head(10)
# Out:
#               notebook_id  \
# 0  ragbench_hotpotqa_0000
# 1  ragbench_hotpotqa_0001
# 2  ragbench_hotpotqa_0002
# 3  ragbench_hotpotqa_0003
# 4  ragbench_hotpotqa_0004
# 5  ragbench_hotpotqa_0005
# 6  ragbench_hotpotqa_0006
# 7  ragbench_hotpotqa_0007
# 8  ragbench_hotpotqa_0008
# 9  ragbench_hotpotqa_0009
#
#                                                                                                                                                                                                question  \
# 0  Which university did one of the key figures in the American documentary film, released in 2015, directed by Malcolm Ingram, pay for, before being drafted 18th overall pick for the New Jersey Nets?
# 1                                                                                                                       Were both Léopold Eyharts and Ulrich Walter a General in the French Air Force?
# ...

# %%
from IPython.display import display, HTML
display(HTML(df.head(3).to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>notebook_id</th>
#       <th>question</th>
#       <th>documents</th>
#       <th>response</th>
#       <th>response_AI</th>
#       <th>similarity_score</th>
#       <th>true_false</th>
#       <th>adherence_score_ragbench</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ragbench_hotpotqa_0000</td>
#       <td>Which university did one of the key figures in the American documentary film, released in 2015, directed by Malcolm Ingram, pay for, before being drafted 18th overall pick for the New Jersey Nets?</td>
# ...

# %%
import pandas as pd
# Tắt hoàn toàn giới hạn độ dài hiển thị text
pd.set_option('display.max_colwidth', None)

# Đọc file
df = pd.read_csv('ragbench_hotpotqa_20260625_025829.csv')

# Xem hàng số 0 (hàng đầu tiên), chỉ lấy 2 cột bạn cần
df.loc[[0], ['response', 'response_AI']]
row_index = 0  # Chọn hàng muốn xem
print("=== RESPONSE GỐC (Ragbench) ===")
print(df.loc[row_index, 'response'])

print("\n=== RESPONSE AI (Hệ thống của bạn) ===")
print(df.loc[row_index, 'response_AI'])
# Out:
# === RESPONSE GỐC (Ragbench) ===
# One of the key figures in the American documentary film, released in 2015, directed by Malcolm Ingram, played college basketball for Stanford University before being drafted 18th overall pick for the New Jersey Nets.
#
# === RESPONSE AI (Hệ thống của bạn) ===
# Based on the information provided in the document, Jason Collins, one of the key figures in the documentary "Out to Win" directed by Malcolm Ingram, played college basketball for Stanford University. The document states that Jason Collins played college basketball for Stanford University before being drafted 18th overall pick by the Houston Rockets, and later played for the New Jersey Nets (among other teams).
#
# Therefore, the university that Jason Collins paid for, before being drafted 18th overall pick for the New Jersey Nets, was Stanford University.
